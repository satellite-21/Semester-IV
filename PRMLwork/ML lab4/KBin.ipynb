# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_table("C:\\Users\\Kartik\\Desktop\\dataset.txt")

# %%
df
# Out:
#       Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0    15.26      14.84       0.8710             5.763            3.312
# 1    14.88      14.57       0.8811             5.554            3.333
# 2    14.29      14.09       0.9050             5.291            3.337
# 3    13.84      13.94       0.8955             5.324            3.379
# 4    16.14      14.99       0.9034             5.658            3.562
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20       0.8783             5.137            2.981
# 206  11.23      12.88       0.8511             5.140            2.795
# 207  13.20      13.66       0.8883             5.236            3.232
# 208  11.84      13.21       0.8521             5.175            2.836
# 209  12.30      13.34       0.8684             5.243            2.974
#
#      Asymmetry coefficient  Length of kernel groove  Class
# 0                    2.221                    5.220      1
# ...

# %%
df1 = df.copy()

# %%
bins = 4
#width would be (max-min)/bins

# %%
col = list(df1.columns)

# %%
df1
# Out:
#       Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0    15.26      14.84       0.8710             5.763            3.312
# 1    14.88      14.57       0.8811             5.554            3.333
# 2    14.29      14.09       0.9050             5.291            3.337
# 3    13.84      13.94       0.8955             5.324            3.379
# 4    16.14      14.99       0.9034             5.658            3.562
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20       0.8783             5.137            2.981
# 206  11.23      12.88       0.8511             5.140            2.795
# 207  13.20      13.66       0.8883             5.236            3.232
# 208  11.84      13.21       0.8521             5.175            2.836
# 209  12.30      13.34       0.8684             5.243            2.974
#
#      Asymmetry coefficient  Length of kernel groove  Class
# 0                    2.221                    5.220      1
# ...

# %%
#FOR AREA
lower_bound = int(min(df['Area']))
m = min(df['Area'])
M = max(df['Area'])
width = (M-m)/bins
for i in range(4):
    df1.loc[(df1['Area'] >= lower_bound + i*width) & (df1['Area'] < lower_bound + (i+1)*width), 'Area'] = i

# %%
df1
# Out:
#      Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0     1.0      14.84       0.8710             5.763            3.312
# 1     1.0      14.57       0.8811             5.554            3.333
# 2     1.0      14.09       0.9050             5.291            3.337
# 3     1.0      13.94       0.8955             5.324            3.379
# 4     2.0      14.99       0.9034             5.658            3.562
# ..    ...        ...          ...               ...              ...
# 205   0.0      13.20       0.8783             5.137            2.981
# 206   0.0      12.88       0.8511             5.140            2.795
# 207   1.0      13.66       0.8883             5.236            3.232
# 208   0.0      13.21       0.8521             5.175            2.836
# 209   0.0      13.34       0.8684             5.243            2.974
#
#      Asymmetry coefficient  Length of kernel groove  Class
# 0                    2.221                    5.220      1
# ...

# %%
#FOR PERIMETER
lower_bound = int(min(df['Perimeter']))
m = min(df['Perimeter'])
M = max(df['Perimeter'])
width = (M-m)/bins
for i in range(4):
    df1.loc[(df1['Perimeter'] >= lower_bound + i*width) & (df1['Perimeter'] < lower_bound + (i+1)*width), 'Perimeter'] = i
df1
# Out:
#      Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0     1.0        2.0       0.8710             5.763            3.312
# 1     1.0        2.0       0.8811             5.554            3.333
# 2     1.0        1.0       0.9050             5.291            3.337
# 3     1.0        1.0       0.8955             5.324            3.379
# 4     2.0        2.0       0.9034             5.658            3.562
# ..    ...        ...          ...               ...              ...
# 205   0.0        0.0       0.8783             5.137            2.981
# 206   0.0        0.0       0.8511             5.140            2.795
# 207   1.0        1.0       0.8883             5.236            3.232
# 208   0.0        1.0       0.8521             5.175            2.836
# 209   0.0        1.0       0.8684             5.243            2.974
#
#      Asymmetry coefficient  Length of kernel groove  Class
# 0                    2.221                    5.220      1
# ...

# %%
#FOR Compactness
lower_bound = (min(df['Compactness']))
m = min(df['Compactness'])
M = max(df['Compactness'])
width = (M-m)/bins
for i in range(4):
    df1.loc[(df1['Compactness'] >= lower_bound + i*width) & (df1['Compactness'] < lower_bound + (i+1)*width), 'Compactness'] = i
df1
# Out:
#      Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0     1.0        2.0          2.0               3.0            2.000
# 1     1.0        2.0          2.0               3.0            2.000
# 2     1.0        1.0          3.0               2.0            2.000
# 3     1.0        1.0          3.0               2.0            2.000
# 4     2.0        2.0          3.0               3.0            3.562
# ..    ...        ...          ...               ...              ...
# 205   0.0        0.0          2.0               2.0            0.000
# 206   0.0        0.0          1.0               2.0            0.000
# 207   1.0        1.0          2.0               2.0            2.000
# 208   0.0        1.0          1.0               2.0            0.000
# 209   0.0        1.0          2.0               2.0            0.000
#
#      Asymmetry coefficient  Length of kernel groove  Class
# 0                    0.000                      2.0      1
# ...

# %%
#FOR Compactness
lower_bound = (min(df['Length of Kernel']))
m = min(df['Length of Kernel'])
M = max(df['Length of Kernel'])
width = (M-m)/bins
for i in range(4):
    df1.loc[(df1['Length of Kernel'] >= lower_bound + i*width) & (df1['Length of Kernel'] < lower_bound + (i+1)*width), 'Length of Kernel'] = i
df1
# Out:
#      Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0     1.0        2.0          2.0               3.0            2.000
# 1     1.0        2.0          2.0               3.0            2.000
# 2     1.0        1.0          3.0               2.0            2.000
# 3     1.0        1.0          3.0               2.0            2.000
# 4     2.0        2.0          3.0               3.0            3.562
# ..    ...        ...          ...               ...              ...
# 205   0.0        0.0          2.0               2.0            0.000
# 206   0.0        0.0          1.0               2.0            0.000
# 207   1.0        1.0          2.0               2.0            2.000
# 208   0.0        1.0          1.0               2.0            0.000
# 209   0.0        1.0          2.0               2.0            0.000
#
#      Asymmetry coefficient  Length of kernel groove  Class
# 0                    0.000                      2.0      1
# ...

# %%
#FOR Compactness
lower_bound = (min(df['Width of Kernel']))
m = min(df['Width of Kernel'])
M = max(df['Width of Kernel'])
width = (M-m)/bins
for i in range(4):
    df1.loc[(df1['Width of Kernel'] >= lower_bound + i*width) & (df1['Width of Kernel'] < lower_bound + (i+1)*width), 'Width of Kernel'] = i
df1
# Out:
#      Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0     1.0        2.0          2.0               3.0              2.0
# 1     1.0        2.0          2.0               3.0              2.0
# 2     1.0        1.0          3.0               2.0              2.0
# 3     1.0        1.0          3.0               2.0              2.0
# 4     2.0        2.0          3.0               3.0              2.0
# ..    ...        ...          ...               ...              ...
# 205   0.0        0.0          2.0               2.0              0.0
# 206   0.0        0.0          1.0               2.0              0.0
# 207   1.0        1.0          2.0               2.0              2.0
# 208   0.0        1.0          1.0               2.0              0.0
# 209   0.0        1.0          2.0               2.0              0.0
#
#      Asymmetry coefficient  Length of kernel groove  Class
# 0                    0.000                      2.0      1
# ...

# %%
#FOR Compactness
lower_bound = (min(df['Asymmetry coefficient']))
m = min(df['Asymmetry coefficient'])
M = max(df['Asymmetry coefficient'])
width = (M-m)/bins
for i in range(4):
    df1.loc[(df1['Asymmetry coefficient'] >= lower_bound + i*width) & (df1['Asymmetry coefficient'] < lower_bound + (i+1)*width), 'Asymmetry coefficient'] = i
df1
# Out:
#      Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0     1.0        2.0          2.0               3.0              2.0
# 1     1.0        2.0          2.0               3.0              2.0
# 2     1.0        1.0          3.0               2.0              2.0
# 3     1.0        1.0          3.0               2.0              2.0
# 4     2.0        2.0          3.0               3.0              2.0
# ..    ...        ...          ...               ...              ...
# 205   0.0        0.0          2.0               2.0              0.0
# 206   0.0        0.0          1.0               2.0              0.0
# 207   1.0        1.0          2.0               2.0              2.0
# 208   0.0        1.0          1.0               2.0              0.0
# 209   0.0        1.0          2.0               2.0              0.0
#
#      Asymmetry coefficient  Length of kernel groove  Class
# 0                      0.0                      2.0      1
# ...

# %%
#FOR Compactness
lower_bound = (min(df['Length of kernel groove']))
m = min(df['Length of kernel groove'])
M = max(df['Length of kernel groove'])
width = (M-m)/bins
for i in range(4):
    df1.loc[(df1['Length of kernel groove'] >= lower_bound + i*width) & (df1['Length of kernel groove'] < lower_bound + (i+1)*width), 'Length of kernel groove'] = i
df1
# Out:
#      Area  Perimeter  Compactness  Length of Kernel  Width of Kernel  \
# 0     1.0        2.0          2.0               3.0              2.0
# 1     1.0        2.0          2.0               3.0              2.0
# 2     1.0        1.0          3.0               2.0              2.0
# 3     1.0        1.0          3.0               2.0              2.0
# 4     2.0        2.0          3.0               3.0              2.0
# ..    ...        ...          ...               ...              ...
# 205   0.0        0.0          2.0               2.0              0.0
# 206   0.0        0.0          1.0               2.0              0.0
# 207   1.0        1.0          2.0               2.0              2.0
# 208   0.0        1.0          1.0               2.0              0.0
# 209   0.0        1.0          2.0               2.0              0.0
#
#      Asymmetry coefficient  Length of kernel groove  Class
# 0                      0.0                      2.0      1
# ...

# %%
sns.histplot(data=df1, x="Area", hue="Class")
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Count'>

# %%
sns.histplot(data=df1, x="Perimeter", hue="Class")
# Out:
# <AxesSubplot:xlabel='Perimeter', ylabel='Count'>

# %%
sns.histplot(data=df1, x="Compactness", hue="Class")
# Out:
# <AxesSubplot:xlabel='Compactness', ylabel='Count'>

# %%
sns.histplot(data=df1, x="Length of Kernel", hue="Class")
# Out:
# <AxesSubplot:xlabel='Length of Kernel', ylabel='Count'>

# %%
sns.histplot(data=df1, x="Width of Kernel", hue="Class")
# Out:
# <AxesSubplot:xlabel='Width of Kernel', ylabel='Count'>

# %%
sns.histplot(data=df1, x="Asymmetry coefficient", hue="Class")
# Out:
# <AxesSubplot:xlabel='Asymmetry coefficient', ylabel='Count'>

# %%
sns.histplot(data=df1, x="Length of kernel groove", hue="Class")
# Out:
# <AxesSubplot:xlabel='Length of kernel groove', ylabel='Count'>

# %%
sns.histplot(data=df1, x="Class", hue="Class")
# Out:
# <AxesSubplot:xlabel='Class', ylabel='Count'>

# %%
sns.histplot(data=df1, x="Area", hue="Area")
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Count'>

# %%
sns.histplot(data=df1, x="Perimeter", hue="Perimeter")
# Out:
# <AxesSubplot:xlabel='Perimeter', ylabel='Count'>

# %%
sns.histplot(data=df1, x="Compactness", hue="Compactness")
# Out:
# <AxesSubplot:xlabel='Compactness', ylabel='Count'>

# %%
sns.histplot(data=df1, x="Length of Kernel", hue="Length of Kernel")
# Out:
# <AxesSubplot:xlabel='Length of Kernel', ylabel='Count'>

# %%
sns.histplot(data=df1, x="Width of Kernel", hue="Width of Kernel")
# Out:
# <AxesSubplot:xlabel='Width of Kernel', ylabel='Count'>

# %%
sns.histplot(data=df1, x="Asymmetry coefficient", hue="Asymmetry coefficient")
# Out:
# <AxesSubplot:xlabel='Asymmetry coefficient', ylabel='Count'>

# %%
sns.histplot(data=df1, x="Length of kernel groove", hue="Length of kernel groove", kde=False)
# Out:
# <AxesSubplot:xlabel='Length of kernel groove', ylabel='Count'>
